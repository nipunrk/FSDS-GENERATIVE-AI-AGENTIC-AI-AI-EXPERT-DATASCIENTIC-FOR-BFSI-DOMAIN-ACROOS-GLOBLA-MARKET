# %% [markdown]
# #package installer

# %%
x =sqrt(5)
x
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 x =sqrt(5)
#       2 x
#
# NameError: name 'sqrt' is not defined

# %%
import math as m
math.sqrt(25)
# Out:
# 5.0

# %%
x
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 x
#
# NameError: name 'x' is not defined

# %%
x=sqrt(25)
x
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 x=sqrt(25)
#       2 x
#
# NameError: name 'sqrt' is not defined

# %%
x =math.sqrt(25)
x
# Out:
# 5.0

# %%
print(math.floor(2.9))
# Out:
# 2

# %%
print(math.ceil(2.9))
# Out:
# 3

# %%
print(math.pow(2,4))
# Out:
# 16.0

# %%
from math import sqrt,pow,floor,ceil
print(round(pow(2,3)))
print(sqrt(9))
print(floor(1.7))
print(ceil(1.7))
# Out:
# 8
# 3.0
# 1
# 2

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
import keyword
len(keyword.kwlist)
# Out:
# 35

# %%
help()
# Out:
# Welcome to Python 3.12's help utility! If this is your first time using
# Python, you should definitely check out the tutorial at
# https://docs.python.org/3.12/tutorial/.
#
# Enter the name of any module, keyword, or topic to get help on writing
# Python programs and using Python modules.  To get a list of available
# modules, keywords, symbols, or topics, enter "modules", "keywords",
# "symbols", or "topics".
#
# Each module also comes with a one-line summary of what it does; to list
# the modules whose name or summary contain a given string such as "spam",
# enter "modules spam".
#
# To quit this help utility and return to the interpreter,
# enter "q" or "quit".
# help>  keyword
# Help on module keyword:
#
# NAME
#     keyword - Keywords (from "Grammar/python.gram")
#
# MODULE REFERENCE
#     https://docs.python.org/3.12/library/keyword.html
#
#     The following documentation is automatically generated from the Python
# ...

# %% [markdown]
# input()

# %%
x= input()
y = input()
z=x+y
print(z)
# Out:
#  3
#  5
# 35

# %%
x1= int(input('Enter 1st number'))
y1 = int(input('Enter 2st number'))
z1=x1+y1
print(z1)
# Out:
# Enter 1st number 8
# Enter 2st number 6
# 14

# %%
x2= input('Enter 1st number')
g=int(x2)
y2 = input('Enter 2st number')
o=int(y2)
z2=g+o
print(z2)
# Out:
# Enter 1st number 3
# Enter 2st number 2
# 5

# %%
ch =input('enter a charachter')[0]
print(ch)
# Out:
# enter a charachter nipun
# n

# %%
ch =input('enter a charachter')[3]
print(ch)
# Out:
# enter a charachter nipun
# u

# %%
ch =input('enter a charachter')[3:]
print(ch)
# Out:
# enter a charachter nipun
# un

# %%
ch =input('enter a charachter')
print(ch)
# Out:
# enter a charachter 5+6-3+2
# 5+6-3+2

# %%
ch = eval(input('enter a charachter'))
print(ch)
# Out:
# enter a charachter 5+6-3+2
# 10

# %%
ch = int(input('enter a charachter'))
print(ch)
# Out:
# enter a charachter 5+6-3+2
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 ch = int(input('enter a charachter'))
#       2 print(ch)
#
# ValueError: invalid literal for int() with base 10: '5+6-3+2'

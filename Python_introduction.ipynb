# %% [markdown]
# ##Work With number

# %%
8
# Out:
# 8

# %%
8+1
# Out:
# 9

# %%
8-6
# Out:
# 2

# %%
8*1
# Out:
# 8

# %%
8/3   # float division
# Out:
# 2.6666666666666665

# %%
8//3 # int division
# Out:
# 2

# %%
2**4
# Out:
# 16

# %%
2**2
# Out:
# 4

# %% [markdown]
# #bodmas(bracket/order/division/multiplication/add/sub)

# %%
10+3-2*2
# Out:
# 9

# %%
10+(3-2)*2
# Out:
# 12

# %%
10 % 2 #remider
# Out:
# 0

# %% [markdown]
# #Work with Text

# %%
Welcome team to brand journey for 6-7 month
# Out:
#   Cell In[18], line 1
#     Welocme team to brand journey for 6-7 month
#             ^
# SyntaxError: invalid syntax

# %%
'Welcome team to brand journey for 6-7 month' #single quotes
# Out:
# 'Welcome team to brand journey for 6-7 month'

# %%
"Welcome team to brand journey for 6-7 month" # double quotes
# Out:
# 'Welcome team to brand journey for 6-7 month'

# %%
'Welcome team to brand '
'journey for 6-7 month'
# Out:
# 'journey for 6-7 month'

# %%
'''Welcome team to brand 
journey for 6-7 month'''
# Out:
# 'Welcome team to brand \njourney for 6-7 month'

# %% [markdown]
# #Python variable
# - variable = value(variable = identifier = Object)
# - identifier = value
# - object = value

# %%
v= 8
v
# Out:
# 8

# %%
Prakash =  'Data Scientist'
Prakash
# Out:
# 'Data Scientist'

# %%
type(Prakash)
# Out:
# str

# %%
type(v)
# Out:
# int

# %%
v =8.3

# %%
type(v)
# Out:
# float

# %% [markdown]
# #rule to define python variable

# %%
var = 45 #case sensitive
Var
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[45], line 2
#       1 var = 45 #case sensitive
# ----> 2 Var
#
# NameError: name 'Var' is not defined

# %%
var = 45
var
# Out:
# 45

# %%
1var = 25 # cant start with digit but it can end with digit
1var
# Out:
#   Cell In[46], line 1
#     1var = 25 # cant start with digit but it can end with digit
#     ^
# SyntaxError: invalid decimal literal

# %%
var$ = 25 # special character not allowed
# Out:
#   Cell In[47], line 1
#     var$ = 25 # special character not allowed
#        ^
# SyntaxError: invalid syntax

# %%
var_ = 25 # only _ allowed
var_
# Out:
# 25

# %%
import keyword
len(keyword.kwlist)
# Out:
# 35

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
for = 8
for
# Out:
#   Cell In[53], line 1
#     for = 8
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# #python data
# int
# float
# bool
# complex
# string

# %%
i = 45
i
# Out:
# 45

# %%
type()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 type()
#
# TypeError: type() takes 1 or 3 arguments

# %%
type(i)
# Out:
# int

# %%
a=4.5
a
# Out:
# 4.5

# %%
type(a)
# Out:
# float

# %%
f1 = 2e0 # 2 * 1.0

# %%
f1
# Out:
# 2.0

# %%
r = 2e4 # e0-1.0 | e2 - 100.0 | e3 - 1000.0

# %%
r
# Out:
# 20000.0

# %%
type(r)
# Out:
# float

# %%
t = 3.3e2 # 3.3* 100.0

# %%
t
# Out:
# 330.0

# %%
y = 4E3
y
# Out:
# 4000.0

# %% [markdown]
# #boolean

# %%
TRUE
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 TRUE
#
# NameError: name 'TRUE' is not defined

# %%
True
# Out:
# True

# %%
flase
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 flase
#
# NameError: name 'flase' is not defined

# %%
False
# Out:
# False

# %%
True + False # inside emeroy true is 1 and false 0
# Out:
# 1

# %%
False + False
# Out:
# 0

# %%
False * True
# Out:
# 0

# %%
True * False
# Out:
# 0

# %%
True * True
# Out:
# 1

# %%
False/ True
# Out:
# 0.0

# %%
False // True
# Out:
# 0

# %% [markdown]
# #complex
# a+bj(a- real part & b - imaginary & j is square root of -1)

# %%
c=10+20j
c
# Out:
# (10+20j)

# %%
type(c)
# Out:
# complex

# %%
c.real
# Out:
# 10.0

# %%
c.imag
# Out:
# 20.0

# %%
d=20+30j

# %%
c+d
# Out:
# (30+50j)

# %%
c.real + d.imag
# Out:
# 40.0

# %% [markdown]
# #String

# %%
s = 'Character'

# %%
s
# Out:
# 'Character'

# %%
t="under"

# %%
t
# Out:
# 'under'

# %%
y= '''Welcome to ds ai,gen ai,
      agent ai jouney
      program'''

# %%
y
# Out:
# 'Welcome to ds ai,gen ai,\n      agent ai jouney\n      program'

# %%
len(y)
# Out:
# 60

# %%
len(t)
# Out:
# 5

# %%
2+3
10+5
# Out:
# 15

# %%
2+3
10+5
10/5
10//5
# Out:
# 2

# %%
print(2+3)
print(10+5)
print(10/5)
print(10//2)
# Out:
# 5
# 15
# 2.0
# 5

# %%
print(t)
id(t)
# Out:
# under
# 2205335928048

# %%
t1= "under"

# %%
print(t1)
id(t1)
# Out:
# under
# 2205335928048

# %%
p,q,r = 10,20,30

# %% [markdown]
# #string indexing

# %%
h= 'hello team'
h
# Out:
# 'hello team'

# %%
type (h)
# Out:
# str

# %%
len(h)
# Out:
# 10

# %%
h
# Out:
# 'hello team'

# %%
h[0]
# Out:
# 'h'

# %%
h[-4]
# Out:
# 't'

# %%
h[12]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 h[12]
#
# IndexError: string index out of range

# %% [markdown]
# #Type casting

# %%
int(2.3) #float to int
# Out:
# 2

# %%
int(2.3,3.4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 int(2.3,3.4)
#
# TypeError: 'float' object cannot be interpreted as an integer

# %%
int(True)
# Out:
# 1

# %%
int(False)
# Out:
# 0

# %%
int(1+2j)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 int(1+2j)
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'complex'

# %%
int('10')
# Out:
# 10

# %%
int('Hi')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 int('Hi')
#
# ValueError: invalid literal for int() with base 10: 'Hi'

# %%
float(8)
# Out:
# 8.0

# %%
float(8,9)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 float(8,9)
#
# TypeError: float expected at most 1 argument, got 2

# %%
float(False)
# Out:
# 0.0

# %%
float(True)
# Out:
# 1.0

# %%
float(1+2j)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 float(1+2j)
#
# TypeError: float() argument must be a string or a real number, not 'complex'

# %%
float('10')
# Out:
# 10.0

# %%
float('hi')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 float('hi')
#
# ValueError: could not convert string to float: 'hi'

# %%
bool(1)
# Out:
# True

# %%
bool(5)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool(3.3)
# Out:
# True

# %%
bool( )
# Out:
# False

# %%
bool(_)
# Out:
# False

# %%
bool('10')
# Out:
# True

# %%
bool(1+2j)
# Out:
# True

# %%
bool('Char')
# Out:
# True

# %%
complex(10)
# Out:
# (10+0j)

# %%
complex(10,20)
# Out:
# (10+20j)

# %%
complex(10.5)
# Out:
# (10.5+0j)

# %%
complex(10,20,30)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 complex(10,20,30)
#
# TypeError: complex() takes at most 2 arguments (3 given)

# %%
complex('10')
# Out:
# (10+0j)

# %%
complex(True)
# Out:
# (1+0j)

# %%
complex(False)
# Out:
# 0j

# %%
complex(1,2.3)
# Out:
# (1+2.3j)

# %%
complex('hi')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 complex('hi')
#
# ValueError: complex() arg is a malformed string

# %%
complex(True,False)
# Out:
# (1+0j)

# %%
complex(False,True)
# Out:
# 1j

# %%
str(10)
# Out:
# '10'

# %%
str(10.1)
# Out:
# '10.1'

# %%
str(True)
# Out:
# 'True'

# %%
str(False)
# Out:
# 'False'

# %%
str(10+2j)
# Out:
# '(10+2j)'

# %%
str(int(True))
# Out:
# '1'

# %%
print(10)
print(10,20)
print('python')
print(20,50,60,70)
print(10,'hello',2.3,1+2j)
# Out:
# 10
# 10 20
# python
# 20 50 60 70
# 10 hello 2.3 (1+2j)

# %%
a=20
b=30
c=a+b
print(c)
# Out:
# 50

# %%
a=20
b=30
c=a+b
print('the additon of',a,'and',b,'is=',c)
# Out:
# the additon of 20 and 30 is= 50

# %%
t,y =30,40
z=t+y
print('The addtion of {} and {} is = {}'.format(t,y,z))
# Out:
# The addtion of 30 and 40 is = 70

# %%
t,y =30,40
z=t+y
n=t-y
print('The addtion of {} and {} is = {}'.format(t,y,z))
print('The subtract of {} and {} is = {}'.format(t,y,n))
# Out:
# The addtion of 30 and 40 is = 70
# The subtract of 30 and 40 is = -10

# %%
print('hello')
print('good night')
# Out:
# hello
# good night

# %%
print('hello',end=' ')
print('good night')
# Out:
# hello good night

# %%
4+5
# Out:
# 9

# %%
_+3
# Out:
# 12

# %%
_+7
# Out:
# 19

# %%
_-5
# Out:
# 14

# %%
s='hello Team'

# %%
s[0]
# Out:
# 'h'

# %%
s[-1]
# Out:
# 'm'

# %%
s[7]
# Out:
# 'e'

# %%
s[5]
# Out:
# ' '

# %%
s[4:6]
# Out:
# 'o '

# %%
s[2:7]
# Out:
# 'llo T'

# %% [markdown]
# #string slicing

# %%
s8='prakash'

# %%
s8
# Out:
# 'prakash'

# %%
s8[:]
# Out:
# 'prakash'

# %%
s8[1:4]
# Out:
# 'rak'

# %%
s8[3:]
# Out:
# 'kash'

# %%
s8[:9]
# Out:
# 'prakash'

# %%
s8[:3]
# Out:
# 'pra'

# %%
s8[8[
# Out:
#   Cell In[9], line 1
#     s8[8[
#          ^
# SyntaxError: incomplete input

# %%
s8[6]
# Out:
# 'h'

# %%
s8[-4]
# Out:
# 'k'

# %%
s8[-1]
# Out:
# 'h'

# %%
s8[1:]
# Out:
# 'rakash'

# %% [markdown]
# #operator
# Arithmetic operator

# %%
x1 , y1 =10,5

# %%
x1+y1
# Out:
# 15

# %%
x1-y1
# Out:
# 5

# %%
x1/y1 #int division
# Out:
# 2.0

# %%
x1//y1  #float division
# Out:
# 2

# %%
x1%y1  #reminder
# Out:
# 0

# %%
x1*y1
# Out:
# 50

# %%
x1**y1
# Out:
# 100000

# %%
3**2
# Out:
# 9

# %%
3 ** 3
# Out:
# 27

# %% [markdown]
# #Assignment operator

# %%
x=2
x
# Out:
# 2

# %%
x+=2
x
# Out:
# 4

# %%
x+=1
x
# Out:
# 5

# %%
x/=2
x
# Out:
# 1.25

# %%
x//=2
x
# Out:
# 0.0
